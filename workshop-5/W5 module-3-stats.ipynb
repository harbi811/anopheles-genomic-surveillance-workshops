# %% [markdown]
# ![banner](../banner.jpg)
#
# ***[Workshop 5](about) - Training course in data analysis for genomic surveillance of African malaria vectors***
#
# ---

# %% [markdown]
# # Module 3 - Genetic diversity summary statistics
#
# **Theme: Analysis**
#
# This module covers how to compute genetic diversity summary statistics, which are a convenient and informative way to quantify and compare diversity in different mosquito populations.

# %% [markdown]
# ## Learning objectives
#
# At the end of this module you will be able to:
#
# * Select cohorts for comparative analysis of genetic diversity
# * Compute nucleotide diversity, Watterson's estimator and Tajima's D
# * Plot diversity statistics for multiple cohorts
# * Interpret the results

# %% [markdown]
# ## Lecture

# %% [markdown]
# ### English

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ohKfiu_WC-g" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ohKfiu_WC-g" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ### Français

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/pkwpz8cWp44" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/pkwpz8cWp44" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Setup
#
# Install and import the packages we'll need.

# %%
# !pip install -q malariagen_data
# Out:
#      |████████████████████████████████| 101 kB 2.6 MB/s
#      |████████████████████████████████| 9.9 MB 35.8 MB/s
#      |████████████████████████████████| 3.1 MB 31.6 MB/s
#      |████████████████████████████████| 3.6 MB 34.3 MB/s
#      |████████████████████████████████| 191 kB 55.7 MB/s
#      |████████████████████████████████| 3.7 MB 47.3 MB/s
#      |████████████████████████████████| 301 kB 55.8 MB/s
#      |████████████████████████████████| 7.2 MB 25.3 MB/s
#      |████████████████████████████████| 55 kB 2.2 MB/s
#      |████████████████████████████████| 1.6 MB 49.5 MB/s
#      |████████████████████████████████| 6.7 MB 29.4 MB/s
#   Building wheel for asciitree (setup.py) ... done

# %%
import malariagen_data
import plotly.express as px

# %% [markdown]
# Here we will compute summary statistics using data from millions of SNPs. This can take some time, so we will use Google Drive to save results and avoid having to rerun computations. To do this we first need to mount Google Drive to our colab VM:

# %%
try:
    from google.colab import drive
    drive.mount("drive")
except ImportError:
    pass
# Out:
# Mounted at drive

# %% [markdown]
# Configure access to MalariaGEN data in Google Cloud.

# %%
ag3 = malariagen_data.Ag3(
    results_cache="drive/MyDrive/malariagen_data_cache"
)
ag3
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL             : gs://vo_agam_release/
# Data releases available : 3.0
# Results cache           : /content/drive/MyDrive/malariagen_data_cache
# Cohorts analysis        : 20220608
# Species analysis        : aim_20220528
# Site filters analysis   : dt_20200416
# Software version        : malariagen_data 7.1.1
# Client location         : South Carolina, US (colab)
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact data@malariagen.net. For API documentation see
# https://malariagen.github.io/vector-data/ag3/api.html

# %% [markdown]
# ## Selecting cohorts
#
# In this module we will be comparing genetic diversity between mosquitoes representing different geographical locations, time points and species. Before we begin any comparative analysis of genetic diversity, we first need to decide how to group the mosquitoes we've sequenced into cohorts. Each cohort we define will represent a sample of mosquitoes from a given time, place and species.
#
# Let's first browse the different sample locations for which we have data. In [workshop 1, module 2](https://anopheles-genomic-surveillance.github.io/workshop-1/module-2-sample-metadata.html) we looked at how to create an interactive map with sampling locations using ipyleaflet. Because this is something we want to do often, we've added a convenience function `plot_samples_interactive_map()` to do this for you. This will plot a map showing sampling locations for all available samples.

# %%
ag3.plot_samples_interactive_map()
# Out:
# Load sample metadata:   0%|          | 0/28 [00:00<?, ?it/s]
# Map(center=[-2, 20], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %% [markdown]
# For the purposes of this module we will begin by focusing on Tanzania. To get more information on the numbers of samples available from Tanzania, we can use pandas to create a pivot table as we also illustrated in [workshop 1, module 2](https://anopheles-genomic-surveillance.github.io/workshop-1/module-2-sample-metadata.html). Again, because we do this often, we've created a convenience function `count_samples()`.

# %%
ag3.count_samples(
    sample_query="country == 'Tanzania'"
)
# Out:
# taxon                                             arabiensis  gambiae  gcx3
# country  admin1_iso admin1_name admin2_name year
# Tanzania TZ-05      Kagera      Muleba      2015         137       32     1
#          TZ-13      Mara        Tarime      2012          47        0     0
#          TZ-25      Tanga       Muheza      2013           1       32    10
#          TZ-26      Manyara     Moshi       2012          40        0     0

# %% [markdown]
# When grouping samples by geographical location, we sometimes can choose whether to aggregate data from nearby locations, or whether to keep them separate. In general, we want the finest spatial granularity possible, but we also need enough samples to make reasonable estimates of genetic diversity, and so we might have to make a trade-off between granularity and sample size.
#
# Similarly, when grouping samples by date of collection, we can choose whether to aggregate data from the same month, season or year. Again, in general we would prefer the finest temporal granularity possible, but might also need sufficient sample size.
#
# For computing diversity summary statistics, there is no hard-and-fast rule about how many samples are needed, but a sample size of 10 is probably the bare minimum we would consider, and we would prefer more if possible.
#
# To simplify grouping of mosquitoes into cohorts, we have predefined some metadata columns which provide cohort labels at different levels of granularity. Let's take a peek at the sample metadata:

# %%
df_samples_tz = ag3.sample_metadata(
    sample_query="country == 'Tanzania'"
)
df_samples_tz.head()
# Out:
#   sample_id partner_sample_id    contributor   country location  year  month  \
# 0  BL0046-C        Plate_C_H6  Bilali Kabula  Tanzania   Muleba  2015      6
# 1  BL0047-C        Plate_F_D4  Bilali Kabula  Tanzania   Muleba  2015      3
# 2  BL0048-C        Plate_F_E4  Bilali Kabula  Tanzania   Muleba  2015      3
# 3  BL0049-C        Plate_F_F4  Bilali Kabula  Tanzania   Muleba  2015      3
# 4  BL0050-C        Plate_F_G4  Bilali Kabula  Tanzania   Muleba  2015      3
#
#    latitude  longitude sex_call  ...                    aim_species  \
# 0    -1.962     31.621        F  ...  intermediate_gambiae_coluzzii
# 1    -1.962     31.621        F  ...                     arabiensis
# 2    -1.962     31.621        F  ...                     arabiensis
# 3    -1.962     31.621        F  ...                     arabiensis
# 4    -1.962     31.621        F  ...                     arabiensis
#
#   country_iso  admin1_name  admin1_iso  admin2_name       taxon  \
# 0         TZA       Kagera       TZ-05       Muleba        gcx3
# 1         TZA       Kagera       TZ-05       Muleba  arabiensis
# 2         TZA       Kagera       TZ-05       Muleba  arabiensis
# 3         TZA       Kagera       TZ-05       Muleba  arabiensis
# 4         TZA       Kagera       TZ-05       Muleba  arabiensis
#
#   cohort_admin1_year cohort_admin1_month      cohort_admin2_year  \
# 0    TZ-05_gcx3_2015  TZ-05_gcx3_2015_06  TZ-05_Muleba_gcx3_2015
# 1    TZ-05_arab_2015  TZ-05_arab_2015_03  TZ-05_Muleba_arab_2015
# 2    TZ-05_arab_2015  TZ-05_arab_2015_03  TZ-05_Muleba_arab_2015
# 3    TZ-05_arab_2015  TZ-05_arab_2015_03  TZ-05_Muleba_arab_2015
# 4    TZ-05_arab_2015  TZ-05_arab_2015_03  TZ-05_Muleba_arab_2015
#
#          cohort_admin2_month
# 0  TZ-05_Muleba_gcx3_2015_06
# 1  TZ-05_Muleba_arab_2015_03
# 2  TZ-05_Muleba_arab_2015_03
# 3  TZ-05_Muleba_arab_2015_03
# 4  TZ-05_Muleba_arab_2015_03
#
# [5 rows x 27 columns]

# %% [markdown]
# If you scroll to the right, you'll see columns named "cohort_admin1_year", "cohort_admin1_month", "cohort_admin2_year" and "cohort_admin2_month". Each of these columns provides a different set of cohort labels. All are grouped by species (taxon).
#
# For this analysis, let's use the "cohort_admin2_year" column to group samples by administrative level 2 divisions (usually called districts) and year. Here are the cohort labels for the Tanzania samples and the sample sizes.

# %%
df_samples_tz.groupby("cohort_admin2_year").size()
# Out:
# cohort_admin2_year
# TZ-05_Muleba_arab_2015    137
# TZ-05_Muleba_gamb_2015     32
# TZ-05_Muleba_gcx3_2015      1
# TZ-13_Tarime_arab_2012     47
# TZ-25_Muheza_arab_2013      1
# TZ-25_Muheza_gamb_2013     32
# TZ-25_Muheza_gcx3_2013     10
# TZ-26_Moshi_arab_2012      40
# dtype: int64

# %% [markdown]
# We can see there are two cohorts with only 1 sample - these will get dropped from our analysis. Otherwise, all cohorts have at least 10 samples.

# %% [markdown]
# ## Recap: genetic diversity summary statistics
#
# We are going to compute the following three summary statistics for each cohort:
#
# * Nucleotide diversity (`theta_pi`) - This quantifies the average number of differences (mismatches) between any pair of DNA sequences in a cohort. The higher this statistic, the more differences you will expect to see between any pair of randomly sampled DNA sequences.
# * Watterson's estimator (`theta_w`) - This quantifies the number of segregating sites within a cohort, scaled by a constant. The higher this statistic, the more sites are found to be segregating (i.e., polymorphic).
# * Tajima's D (`tajima_d`) - This quantifies the difference between Watterson's estimator and nucleotide diversity, and scales the result by a constant. This statistic is useful because it focuses not on the magnitude but on the architecture of diversity in a cohort, compared to a neutrally evolving population of constant size. Negative values imply an excess of rare alleles, and positive values imply a deficit of rare alleles, relative to a population at equilibrium.

# %% [markdown]
# ## Computing diversity summary statistics
#
# Let's begin by computing these summary statistics in a single cohort. For this we can use the function `cohort_diversity_stats()`. Let's look at the docstring.

# %%
ag3.cohort_diversity_stats?

# %% [markdown]
# Let's now compute the statistics for one of our Tanzanian cohorts, TZ-05_Muleba_gamb_2015.

# %%
stats = ag3.cohort_diversity_stats(
    cohort="TZ-05_Muleba_gamb_2015",
    cohort_size=30,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
stats
# Out:
# Locate CDS_DEG_4 sites:   0%|          | 0/7 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1245 [00:00<?, ?it/s]
# cohort               TZ-05_Muleba_gamb_2015
# theta_pi                           0.021167
# theta_pi_estimate                  0.021173
# theta_pi_bias                     -0.000005
# theta_pi_std_err                     0.0003
# theta_pi_ci_err                    0.001176
# theta_pi_ci_low                    0.020585
# theta_pi_ci_upp                    0.021761
# theta_w                            0.038855
# theta_w_estimate                   0.038854
# theta_w_bias                       0.000001
# theta_w_std_err                    0.000436
# theta_w_ci_err                     0.001709
# theta_w_ci_low                     0.037999
# theta_w_ci_upp                     0.039708
# tajima_d                          -1.635894
# tajima_d_estimate                 -1.635436
# tajima_d_bias                     -0.000459
# tajima_d_std_err                   0.015294
# tajima_d_ci_err                     0.05995
# tajima_d_ci_low                   -1.665411
# tajima_d_ci_upp                   -1.605461
# taxon                               gambiae
# year                                   2015
# month                                [3, 6]
# country                            Tanzania
# admin1_iso                            TZ-05
# admin1_name                          Kagera
# admin2_name                          Muleba
# longitude                            31.621
# latitude                             -1.962
# dtype: object

# %% [markdown]
# This function returns a pandas Series with values of the summary statistics for our requested cohort. The field `theta_pi` contains the value of nucleotide diversity. The field `theta_w` contains the value of Watterson's estimator. The field `tajima_d` contains the value of Tajima's D.
#
# A 95% confidence interval has also been estimated for each of these statistics using a block jackknife procedure. The lower and upper ends of these confidence intervals are given by the fields with the suffixes `_ci_low` and `_ci_upp` respectively. The fields with suffix `_ci_err` give the size of the confidence interval, and is useful for plotting error bars.
#
# It is important to note that, in addition to the `cohort` parameter, we also provided values for the parameters `cohort_size`, `region`, `site_mask` and `site_class`. These parameters are important and can make a big difference to the statistic values obtained.
#
# To illustrate the impact of changing some of these parameters, let's recompute the statistics but providing `cohort_size` of 10 instead of 30.

# %%
stats = ag3.cohort_diversity_stats(
    cohort="TZ-05_Muleba_gamb_2015",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
stats
# Out:
# Compute SNP allele counts:   0%|          | 0/1245 [00:00<?, ?it/s]
# cohort               TZ-05_Muleba_gamb_2015
# theta_pi                           0.021242
# theta_pi_estimate                  0.021247
# theta_pi_bias                     -0.000004
# theta_pi_std_err                   0.000302
# theta_pi_ci_err                    0.001182
# theta_pi_ci_low                    0.020655
# theta_pi_ci_upp                    0.021838
# theta_w                             0.03035
# theta_w_estimate                   0.030352
# theta_w_bias                      -0.000003
# theta_w_std_err                    0.000377
# theta_w_ci_err                     0.001478
# theta_w_ci_low                     0.029613
# theta_w_ci_upp                     0.031092
# tajima_d                          -1.259672
# tajima_d_estimate                 -1.259398
# tajima_d_bias                     -0.000274
# tajima_d_std_err                   0.016672
# tajima_d_ci_err                    0.065353
# tajima_d_ci_low                   -1.292075
# tajima_d_ci_upp                   -1.226721
# taxon                               gambiae
# year                                   2015
# month                                [3, 6]
# country                            Tanzania
# admin1_iso                            TZ-05
# admin1_name                          Kagera
# admin2_name                          Muleba
# longitude                            31.621
# latitude                             -1.962
# dtype: object

# %% [markdown]
# Note that the value of `theta_pi` hasn't changed much, but the values of `theta_w` and `tajima_d` are considerably different. This is because, for many cohorts, there is a strong dependency between these statistics and the cohort size, i.e., the number of samples used to calculate the statistics. Because of this, if we want to make a fair comparison between different cohorts, it is important to use the same cohort size in all cases. If we have a cohort with more samples than our chosen cohort size, the cohort will be randomly downsampled.
#
# Another parameter that makes a big difference is the `site_class` parameter, which defines the type of genomic site used to calculate the diversity statistics. Above we used "CDS_DEG_4" which stands for [4-fold degenerate coding sites](https://en.wikipedia.org/wiki/Codon_degeneracy), i.e., sites within gene coding sequences where none of the possible nucleotide changes will affect the resulting amino acid. These sites are typically under relatively weak selective constraint, because they have little to no impact on the phenotype of the organism.
#
# For illustration, let's contrast this with "CDS_DEG_0" which stands for non-degenerate coding sites, i.e., sites where any nucleotide change will change the amino acid.

# %%
stats = ag3.cohort_diversity_stats(
    cohort="TZ-05_Muleba_gamb_2015",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_0",
)
stats
# Out:
# Locate CDS_DEG_0 sites:   0%|          | 0/5 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1245 [00:00<?, ?it/s]
# cohort               TZ-05_Muleba_gamb_2015
# theta_pi                           0.002492
# theta_pi_estimate                  0.002492
# theta_pi_bias                          -0.0
# theta_pi_std_err                   0.000091
# theta_pi_ci_err                    0.000356
# theta_pi_ci_low                    0.002314
# theta_pi_ci_upp                     0.00267
# theta_w                            0.004047
# theta_w_estimate                   0.004047
# theta_w_bias                      -0.000001
# theta_w_std_err                     0.00013
# theta_w_ci_err                     0.000509
# theta_w_ci_low                     0.003793
# theta_w_ci_upp                     0.004302
# tajima_d                          -1.612858
# tajima_d_estimate                 -1.612861
# tajima_d_bias                      0.000004
# tajima_d_std_err                   0.026732
# tajima_d_ci_err                    0.104788
# tajima_d_ci_low                   -1.665255
# tajima_d_ci_upp                   -1.560467
# taxon                               gambiae
# year                                   2015
# month                                [3, 6]
# country                            Tanzania
# admin1_iso                            TZ-05
# admin1_name                          Kagera
# admin2_name                          Muleba
# longitude                            31.621
# latitude                             -1.962
# dtype: object

# %% [markdown]
# Note that the value of `theta_pi` has now reduced by approximately an order of magnitude. This is because non-degenerate coding sites are subject to much stronger purifying selection than 4-fold degenerate sites.
#
# In this module we are most interested in using comparative analysis of diversity statistics to learn more about demographic differences and changes within our sampled mosquito populations. Hence we will prefer to use sites that are less affected by selection, and will use 4-fold degenerate sites ("CDS_DEG_4") for the remainder of the module.
#
# A final note, above we chose to provide the parameter `region="3L:15,000,000-41,000,000"`, which defines the genome region we will use for diversity calculations. We typically prefer to use chromosome arm 3L because there are no large polymorphic inversions in any of the species we are studying. We also exclude the pericentromeric and telomeric regions because these have reduced diversity due to reduced recombination and hence selection at linked sites.

# %% [markdown]
# ## Comparing diversity between cohorts
#
# Now we have seen how to compute statistics for a single cohort, let's run the same computation but for multiple cohorts, and see how to compare the results.

# %% [markdown]
# ### Example: Tanzania
#
# Sticking with our focus on Tanzania, let's remind ourselves what cohorts and sample sizes are available if we group samples by the "cohort_admin2_year" field, which will group by taxon, district and year.

# %%
df_samples_tz.groupby("cohort_admin2_year").size()
# Out:
# cohort_admin2_year
# TZ-05_Muleba_arab_2015    137
# TZ-05_Muleba_gamb_2015     32
# TZ-05_Muleba_gcx3_2015      1
# TZ-13_Tarime_arab_2012     47
# TZ-25_Muheza_arab_2013      1
# TZ-25_Muheza_gamb_2013     32
# TZ-25_Muheza_gcx3_2013     10
# TZ-26_Moshi_arab_2012      40
# dtype: int64

# %% [markdown]
# If we choose a cohort size of 10 for our comparative analysis, we will be able to analyse 6 cohorts.
#
# To compute diversity for multiple cohorts at the same time, we have provided a `diversity_stats()` function.

# %%
ag3.diversity_stats?

# %% [markdown]
# This function has many of the same parameters we discussed above, except now we provide a `sample_query` parameter to restrict the overall analysis to samples in Tanzania, and we provide a `cohorts` parameter to define how these samples will be grouped into cohorts.

# %%
df_stats_tz_admin2_year = ag3.diversity_stats(
    sample_query="country == 'Tanzania'",
    cohorts="admin2_year",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
df_stats_tz_admin2_year
# Out:
# [INFO] cohort (TZ-05_Muleba_gcx3_2015) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (TZ-05_Muleba_gcx3_2015) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (TZ-25_Muheza_arab_2013) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (TZ-25_Muheza_arab_2013) has insufficient samples (1) for requested cohort size (10), dropping
# Compute SNP allele counts:   0%|          | 0/1577 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/498 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/498 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1245 [00:00<?, ?it/s]
#                    cohort  theta_pi  theta_pi_estimate  theta_pi_bias  \
# 0  TZ-05_Muleba_arab_2015  0.012306           0.012306   6.185033e-07
# 1  TZ-05_Muleba_gamb_2015  0.021242           0.021247  -4.337053e-06
# 2  TZ-13_Tarime_arab_2012  0.012435           0.012435  -3.120599e-07
# 3  TZ-25_Muheza_gamb_2013  0.017705           0.017705   4.563558e-07
# 4  TZ-25_Muheza_gcx3_2013  0.013395           0.013398  -2.958723e-06
# 5   TZ-26_Moshi_arab_2012  0.012374           0.012373   1.310417e-06
#
#    theta_pi_std_err  theta_pi_ci_err  theta_pi_ci_low  theta_pi_ci_upp  \
# 0          0.000224         0.000877         0.011867         0.012744
# 1          0.000302         0.001182         0.020655         0.021838
# 2          0.000220         0.000861         0.012005         0.012866
# 3          0.000290         0.001136         0.017137         0.018273
# 4          0.000342         0.001340         0.012728         0.014068
# 5          0.000219         0.000857         0.011945         0.012801
#
#     theta_w  theta_w_estimate  ...  tajima_d_ci_upp       taxon  year  \
# 0  0.014789          0.014790  ...        -0.658653  arabiensis  2015
# 1  0.030350          0.030352  ...        -1.226721     gambiae  2015
# 2  0.015058          0.015059  ...        -0.681130  arabiensis  2012
# 3  0.018939          0.018935  ...        -0.218096     gambiae  2013
# 4  0.012917          0.012918  ...         0.257321        gcx3  2013
# 5  0.014669          0.014667  ...        -0.604319  arabiensis  2012
#
#        month   country  admin1_iso  admin1_name  admin2_name  longitude  \
# 0  [3, 4, 6]  Tanzania       TZ-05       Kagera       Muleba     31.621
# 1     [3, 6]  Tanzania       TZ-05       Kagera       Muleba     31.621
# 2          8  Tanzania       TZ-13         Mara       Tarime     34.199
# 3          1  Tanzania       TZ-25        Tanga       Muheza     38.948
# 4          1  Tanzania       TZ-25        Tanga       Muheza     38.948
# 5          8  Tanzania       TZ-26      Manyara        Moshi     37.308
#
#    latitude
# 0    -1.962
# 1    -1.962
# 2    -1.431
# 3    -4.940
# 4    -4.940
# 5    -3.482
#
# [6 rows x 31 columns]

# %% [markdown]
# This function returns a pandas DataFrame, where each row contains data about a cohort, and the columns provide the different statistic values and their confidence intervals. Let's take a look at all the available columns:

# %%
df_stats_tz_admin2_year.columns
# Out:
# Index(['cohort', 'theta_pi', 'theta_pi_estimate', 'theta_pi_bias',
#        'theta_pi_std_err', 'theta_pi_ci_err', 'theta_pi_ci_low',
#        'theta_pi_ci_upp', 'theta_w', 'theta_w_estimate', 'theta_w_bias',
#        'theta_w_std_err', 'theta_w_ci_err', 'theta_w_ci_low', 'theta_w_ci_upp',
#        'tajima_d', 'tajima_d_estimate', 'tajima_d_bias', 'tajima_d_std_err',
#        'tajima_d_ci_err', 'tajima_d_ci_low', 'tajima_d_ci_upp', 'taxon',
#        'year', 'month', 'country', 'admin1_iso', 'admin1_name', 'admin2_name',
#        'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# A simple way to visualise these statistics and compare cohorts is to make a bar plot. Let's do this for nucleotide diversity using plotly express.

# %%
px.bar(
    data_frame=df_stats_tz_admin2_year,
    x="cohort",
    y="theta_pi_estimate",
    error_y="theta_pi_ci_err",
    color="taxon",
    height=450,
    width=500,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7c2ee338-2332-4b41-8de2-6f8ca3d13711" class="plotly-graph-div" style="height:450px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c2ee338-2332-4b41-8de2-6f8ca3d13711")) {                    Plotly.newPlot(                        "7c2ee338-2332-4b41-8de2-6f8ca3d13711",                        [{"alignmentgroup":"True","error_y":{"array":[0.0008767828578080531,0.0008610896628349073,0.0008565317306298921]},"hovertemplate":"taxon=arabiensis<br>cohort=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"xaxis":"x","y":[0.012305821385764614,0.012435191358870714,0.012372971080334862],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.001182458864377038,0.001136199721887595]},"hovertemplate":"taxon=gambiae<br>cohort=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"xaxis":"x","y":[0.021246519681427135,0.01770499150805352],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0013401434715671241]},"hovertemplate":"taxon=gcx3<br>cohort=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013"],"xaxis":"x","y":[0.013397633291510242],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fill ...

# %% [markdown]
# Above we chose to colour the bars by taxon, which helps to see some of the patterns in the data. For example, we have three *An. arabiensis* cohorts, all of which have nearly identical nucleotide diversity. We also have two *An. gambiae* cohorts, both of which have higher nucleotide diversity. There is also a significant difference between the two *An. gambiae* cohorts from the east and west of the country. Finally, we have one cohort representing the putative cryptic taxon which we have provisionally labelled gcx3 (see [workshop 4, module 4](https://anopheles-genomic-surveillance.github.io/workshop-4/module-4-taxon-analysis.html)).
#
# We also would like to make similar plots to visualise Watterson's estimator and Tajima's D. Because we'll want to make these plots often, let's define a simple function to make all the plots we need.

# %%
def plot_diversity_stats(
    df_stats, 
    color=None, 
    height=450, 
    template="plotly_white"
):

    # set up common plotting parameters
    hover_name = "cohort"
    hover_data = [
        "taxon",
        "country",
        "admin1_iso",
        "admin1_name",
        "admin2_name",
        "year",
        "month",
    ]
    labels = {
        'theta_pi_estimate': r'$\widehat{\theta}_{\pi}$',
        'theta_w_estimate': r'$\widehat{\theta}_{w}$',
        'tajima_d_estimate': r'$D$',
        'cohort': "Cohort",
        'taxon': 'Taxon',
        'country': "Country",
    }
    category_orders = {
        "taxon": ["arabiensis", "gambiae", "gcx3", "coluzzii", "gcx1", "gcx2"],
    }
    width = 300 + 30 * len(df_stats)

    # nucleotide diversity bar plot
    fig = px.bar(
        data_frame=df_stats,
        x="cohort",
        y="theta_pi_estimate",
        error_y="theta_pi_ci_err",
        title="Nucleotide diversity",
        color=color,
        height=height,
        width=width,
        hover_name=hover_name,
        hover_data=hover_data,
        labels=labels,
        template=template,
        category_orders=category_orders,
    )
    fig.show()

    # watterson estimator bar plot
    fig = px.bar(
        data_frame=df_stats,
        x="cohort",
        y="theta_w_estimate",
        error_y="theta_w_ci_err",
        title="Watterson estimator",
        color=color,
        height=height,
        width=width,
        hover_name=hover_name,
        hover_data=hover_data,
        labels=labels,
        template=template,
        category_orders=category_orders,
    )
    fig.show()

    # tajima's d bar plot
    fig = px.bar(
        data_frame=df_stats,
        x="cohort",
        y="tajima_d_estimate",
        error_y="tajima_d_ci_err",
        title="Tajima's D",
        color=color,
        height=height,
        width=width,
        hover_name=hover_name,
        hover_data=hover_data,
        labels=labels,
        template=template,
        category_orders=category_orders,
    )
    fig.show()

    # scatter plot comparing diversity estimators
    fig = px.scatter(
        data_frame=df_stats,
        x="theta_pi_estimate",
        y="theta_w_estimate",
        error_x="theta_pi_ci_err",
        error_y="theta_w_ci_err",
        title="Diversity estimators",
        color=color,
        width=500,
        height=500,
        hover_name=hover_name,
        hover_data=hover_data,
        labels=labels,
        template=template,
        category_orders=category_orders,
    )
    fig.show()

# %% [markdown]
# Let's now make these plots for our Tanzanian cohorts.

# %%
plot_diversity_stats(df_stats_tz_admin2_year, color="taxon")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8d3af4ac-8155-4085-bb7b-f25de9818315" class="plotly-graph-div" style="height:450px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d3af4ac-8155-4085-bb7b-f25de9818315")) {                    Plotly.newPlot(                        "8d3af4ac-8155-4085-bb7b-f25de9818315",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_y":{"array":[0.0008767828578080531,0.0008610896628349073,0.0008565317306298921]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"xaxis":"x","y":[0.012305821385764614,0.012435191358870714,0.012372971080334862],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.001182458864377038,0.001136199721887595]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"xaxis":"x","y":[0.021246519681427135,0.01770499150805352],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0013401434715671241]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013"],"xaxis":"x","y":[0.013397633291510242],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""} ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="56904fd7-3cbc-443e-97dc-cb4993e6aad8" class="plotly-graph-div" style="height:450px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56904fd7-3cbc-443e-97dc-cb4993e6aad8")) {                    Plotly.newPlot(                        "56904fd7-3cbc-443e-97dc-cb4993e6aad8",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_y":{"array":[0.0009732513776216027,0.0009709442046371612,0.0009124973674744433]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"xaxis":"x","y":[0.01479018822563256,0.015058888895662042,0.014666991750033907],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0014784123971940868,0.0011770314504906056]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"xaxis":"x","y":[0.030352491386682584,0.018935395054669256],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0009724066834559929]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013"],"xaxis":"x","y":[0.012917784533903487],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e84a7940-d2b8-452b-95be-2aa5cb5f74dc" class="plotly-graph-div" style="height:450px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e84a7940-d2b8-452b-95be-2aa5cb5f74dc")) {                    Plotly.newPlot(                        "e84a7940-d2b8-452b-95be-2aa5cb5f74dc",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_y":{"array":[0.09298333949876056,0.10060131875886644,0.10453177863777642]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"xaxis":"x","y":[-0.7051445660180288,-0.7314308240562268,-0.6565852582790553],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.06535341551175326,0.10950056994601909]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"xaxis":"x","y":[-1.2593981283459053,-0.2728466026281025],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.20214467901282857]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013"],"xaxis":"x","y":[0.15624830920460062],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="98241e3c-4c3d-4033-8ab9-09cc23c009cd" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98241e3c-4c3d-4033-8ab9-09cc23c009cd")) {                    Plotly.newPlot(                        "98241e3c-4c3d-4033-8ab9-09cc23c009cd",                        [{"customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_x":{"array":[0.0008767828578080531,0.0008610896628349073,0.0008565317306298921]},"error_y":{"array":[0.0009732513776216027,0.0009709442046371612,0.0009124973674744433]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"arabiensis","orientation":"v","showlegend":true,"x":[0.012305821385764614,0.012435191358870714,0.012372971080334862],"xaxis":"x","y":[0.01479018822563256,0.015058888895662042,0.014666991750033907],"yaxis":"y","type":"scatter"},{"customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_x":{"array":[0.001182458864377038,0.001136199721887595]},"error_y":{"array":[0.0014784123971940868,0.0011770314504906056]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013"],"legendgroup":"gambiae","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"gambiae","orientation":"v","showlegend":true,"x":[0.021246519681427135,0.01770499150805352],"xaxis":"x","y":[0.030352491386682584,0.018935395054669256],"yaxis":"y","type":"scatter"},{"customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_x":{"array":[0.0013401434715671241]},"error_y":{"array":[0.0009724066834559929]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"gcx3","orientation":"v","showlegend":true,"x":[0.013397633291510242],"xaxis":"x","y":[0.012917784533903487],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type": ...

# %% [markdown]
# From the above we can see the following patterns:
#
# * All *An. arabiensis* cohorts have similar diversity, regardless of sampling location.
# * *An. gambiae* cohorts have different diversity between the west and east of the country.
# * The gcx3 cohort is quite different from all other cohorts, and is the only cohort with a positive value for Tajima's D.

# %% [markdown]
# **Exercise 1 (English)**
#
# Uncomment and run the code cells below to repeat the above analysis, but using cohorts grouped by district (administrative level 2) and month.
#
# Do the results change any of our observations about the similarities and differences between species and geographical locations?
#
# Is there any evidence for differences in diversity between different months of sampling?
#
# **Exercice 1 (Français)**
#
# Décommentez et exécutez les cellules de code ci-dessous pour répéter l'analyse ci-dessus, mais en utilisant des cohortes regroupées par district (niveau administratif 2) et mois.
#
# Les résultats modifient-ils certaines de nos observations sur les similitudes et les différences entre les espèces et les emplacements géographiques?
#
# Existe-t-il des preuves de différences de diversité entre les différents mois d'échantillonnage?

# %%
df_samples_tz.groupby("cohort_admin2_month").size()
# Out:
# cohort_admin2_month
# TZ-05_Muleba_arab_2015_03    39
# TZ-05_Muleba_arab_2015_04    10
# TZ-05_Muleba_arab_2015_06    88
# TZ-05_Muleba_gamb_2015_03    13
# TZ-05_Muleba_gamb_2015_06    19
# TZ-05_Muleba_gcx3_2015_06     1
# TZ-13_Tarime_arab_2012_08    47
# TZ-25_Muheza_arab_2013_01     1
# TZ-25_Muheza_gamb_2013_01    32
# TZ-25_Muheza_gcx3_2013_01    10
# TZ-26_Moshi_arab_2012_08     40
# dtype: int64

# %%
df_stats_tz_admin2_month = ag3.diversity_stats(
    sample_query="country == 'Tanzania'",
    cohorts="admin2_month",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
plot_diversity_stats(df_stats_tz_admin2_month, color="taxon")
# Out:
# [INFO] cohort (TZ-05_Muleba_gcx3_2015_06) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (TZ-05_Muleba_gcx3_2015_06) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (TZ-25_Muheza_arab_2013_01) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (TZ-25_Muheza_arab_2013_01) has insufficient samples (1) for requested cohort size (10), dropping
# Compute SNP allele counts:   0%|          | 0/1577 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1577 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1245 [00:00<?, ?it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8699e75d-f664-4569-970f-a98fd3d9f15f" class="plotly-graph-div" style="height:450px; width:570px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8699e75d-f664-4569-970f-a98fd3d9f15f")) {                    Plotly.newPlot(                        "8699e75d-f664-4569-970f-a98fd3d9f15f",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,3],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,4],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,6],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_y":{"array":[0.0008502917024697051,0.0008782335699258992,0.0008544130451253322,0.0008610896628349073,0.0008565317306298921]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"xaxis":"x","y":[0.012479393110095556,0.012496682440614283,0.01246700705892751,0.012435191358870714,0.012372971080334862],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,3],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,6],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0012323801448479374,0.0011987292006040854,0.001136199721887595]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"xaxis":"x","y":[0.021195452007257518,0.02106752800925177,0.01770499150805352],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0013401434715671241]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013_01"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013_01"],"xaxis":"x","y":[0.013397633291510242],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"erro ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4b6ac43e-9656-42b1-a5fd-4ce79b741287" class="plotly-graph-div" style="height:450px; width:570px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b6ac43e-9656-42b1-a5fd-4ce79b741287")) {                    Plotly.newPlot(                        "4b6ac43e-9656-42b1-a5fd-4ce79b741287",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,3],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,4],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,6],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_y":{"array":[0.000919737195144674,0.0009164167717643278,0.0009621863432633652,0.0009709442046371612,0.0009124973674744433]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"xaxis":"x","y":[0.01513110931443085,0.015042961968913951,0.015178903760198445,0.015058888895662042,0.014666991750033907],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,3],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,6],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.00158084951715664,0.0015202771056640277,0.0011770314504906056]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"xaxis":"x","y":[0.030066798480798327,0.029694017681851693,0.018935395054669256],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0009724066834559929]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013_01"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013_01"],"xaxis":"x","y":[0.012917784533903487],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"co ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="58e53c9a-4549-42d1-87c2-aec2c01631fd" class="plotly-graph-div" style="height:450px; width:570px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58e53c9a-4549-42d1-87c2-aec2c01631fd")) {                    Plotly.newPlot(                        "58e53c9a-4549-42d1-87c2-aec2c01631fd",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,3],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,4],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,6],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_y":{"array":[0.1029257818290828,0.09498672133617586,0.10049480637627264,0.10060131875886644,0.10453177863777642]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"xaxis":"x","y":[-0.7356829936003861,-0.7105225757067777,-0.7500368118206585,-0.7314308240562268,-0.6565852582790553],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,3],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,6],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.06431914522687798,0.06680181414423515,0.10950056994601909]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"xaxis":"x","y":[-1.2386145394374024,-1.219550866059332,-0.2728466026281025],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.20214467901282857]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013_01"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["TZ-25_Muheza_gcx3_2013_01"],"xaxis":"x","y":[0.15624830920460062],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"ov ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a38e1a44-5ffe-4fe8-a3c0-28ab31d050d1" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a38e1a44-5ffe-4fe8-a3c0-28ab31d050d1")) {                    Plotly.newPlot(                        "a38e1a44-5ffe-4fe8-a3c0-28ab31d050d1",                        [{"customdata":[["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,3],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,4],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,6],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8]],"error_x":{"array":[0.0008502917024697051,0.0008782335699258992,0.0008544130451253322,0.0008610896628349073,0.0008565317306298921]},"error_y":{"array":[0.000919737195144674,0.0009164167717643278,0.0009621863432633652,0.0009709442046371612,0.0009124973674744433]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_arab_2015_03","TZ-05_Muleba_arab_2015_04","TZ-05_Muleba_arab_2015_06","TZ-13_Tarime_arab_2012_08","TZ-26_Moshi_arab_2012_08"],"legendgroup":"arabiensis","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"arabiensis","orientation":"v","showlegend":true,"x":[0.012479393110095556,0.012496682440614283,0.01246700705892751,0.012435191358870714,0.012372971080334862],"xaxis":"x","y":[0.01513110931443085,0.015042961968913951,0.015178903760198445,0.015058888895662042,0.014666991750033907],"yaxis":"y","type":"scatter"},{"customdata":[["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,3],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,6],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_x":{"array":[0.0012323801448479374,0.0011987292006040854,0.001136199721887595]},"error_y":{"array":[0.00158084951715664,0.0015202771056640277,0.0011770314504906056]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-05_Muleba_gamb_2015_03","TZ-05_Muleba_gamb_2015_06","TZ-25_Muheza_gamb_2013_01"],"legendgroup":"gambiae","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"gambiae","orientation":"v","showlegend":true,"x":[0.021195452007257518,0.02106752800925177,0.01770499150805352],"xaxis":"x","y":[0.030066798480798327,0.029694017681851693,0.018935395054669256],"yaxis":"y","type":"scatter"},{"customdata":[["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_x":{"array":[0.0013401434715671241]},"error_y":{"array":[0.0009724066834559929]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["TZ-25_Muheza_gcx3_2013_01"],"legendgroup":"gcx3","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"gcx3","orientation":"v","showlegend":true,"x":[0.013397633291510242],"xaxis":"x","y":[0.012917784533903487],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay", ...

# %% [markdown]
# ### Example: East Africa
#
# Let's now expand our analysis to include samples from neighbouring countries, to investigate a broader geographical range.
#
# Firstly, let's plot a map to remind ourselves of the available sampling locations.

# %%
ag3.plot_samples_interactive_map()
# Out:
# Map(center=[-2, 20], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %% [markdown]
# From the map we can see that there are two sampling locations in Uganda and one location in Kenya. Let's add these countries and investigate sample sizes.

# %%
ag3.count_samples(
    sample_query="country in ['Tanzania', 'Kenya', 'Uganda']"
)
# Out:
# taxon                                                arabiensis  gambiae  \
# country  admin1_iso admin1_name    admin2_name year
# Kenya    KE-14      Kilifi         Kilifi      2000           0       19
#                                                2007           3        0
#                                                2012          10        0
# Tanzania TZ-05      Kagera         Muleba      2015         137       32
#          TZ-13      Mara           Tarime      2012          47        0
#          TZ-25      Tanga          Muheza      2013           1       32
#          TZ-26      Manyara        Moshi       2012          40        0
# Uganda   UG-E       Eastern Region Tororo      2012          81      112
#          UG-W       Western Region Kanungu     2012           1       95
#
# taxon                                                gcx3  \
# country  admin1_iso admin1_name    admin2_name year
# Kenya    KE-14      Kilifi         Kilifi      2000     0
#                                                2007     0
#                                                2012    54
# Tanzania TZ-05      Kagera         Muleba      2015     1
#          TZ-13      Mara           Tarime      2012     0
#          TZ-25      Tanga          Muheza      2013    10
#          TZ-26      Manyara        Moshi       2012     0
# Uganda   UG-E       Eastern Region Tororo      2012     0
#          UG-W       Western Region Kanungu     2012     0
#
# taxon                                                intermediate_gambcolu_arabiensis
# country  admin1_iso admin1_name    admin2_name year
# Kenya    KE-14      Kilifi         Kilifi      2000                                 0
#                                                2007                                 0
#                                                2012                                 0
# Tanzania TZ-05      Kagera         Muleba      2015                                 0
#          TZ-13      Mara           Tarime      2012                                 0
#          TZ-25      Tanga          Muheza      2013                                 0
#          TZ-26      Manyara        Moshi       2012                                 0
# Uganda   UG-E       Eastern Region Tororo      2012                                 1
#          UG-W       Western Region Kanungu     2012                                 0

# %% [markdown]
# Let's also confirm how many cohorts would be available if we continued to use the "cohort_admin2_year" field to group by taxon, district and year.

# %%
ag3.sample_metadata(
    sample_query="country in ['Tanzania', 'Kenya', 'Uganda']"
).groupby("cohort_admin2_year").size()
# Out:
# cohort_admin2_year
# KE-14_Kilifi_arab_2007      3
# KE-14_Kilifi_arab_2012     10
# KE-14_Kilifi_gamb_2000     19
# KE-14_Kilifi_gcx3_2012     54
# TZ-05_Muleba_arab_2015    137
# TZ-05_Muleba_gamb_2015     32
# TZ-05_Muleba_gcx3_2015      1
# TZ-13_Tarime_arab_2012     47
# TZ-25_Muheza_arab_2013      1
# TZ-25_Muheza_gamb_2013     32
# TZ-25_Muheza_gcx3_2013     10
# TZ-26_Moshi_arab_2012      40
# UG-E_Tororo_arab_2012      81
# UG-E_Tororo_gamb_2012     112
# UG-W_Kanungu_arab_2012      1
# UG-W_Kanungu_gamb_2012     95
# dtype: int64

# %% [markdown]
# Here, sticking with a cohort size of 10 will allow us to include 3 cohorts from Kenya and 3 cohorts from Uganda.
#
# Let's now compute and plot diversity stats for all cohorts.

# %%
df_stats_tz_ke_ug_admin2_year = ag3.diversity_stats(
    sample_query="country in ['Tanzania', 'Kenya', 'Uganda']",
    cohorts="admin2_year",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)
df_stats_tz_ke_ug_admin2_year
# Out:
# [INFO] cohort (KE-14_Kilifi_arab_2007) has insufficient samples (3) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (KE-14_Kilifi_arab_2007) has insufficient samples (3) for requested cohort size (10), dropping
# [INFO] cohort (TZ-05_Muleba_gcx3_2015) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (TZ-05_Muleba_gcx3_2015) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (TZ-25_Muheza_arab_2013) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (TZ-25_Muheza_arab_2013) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (UG-W_Kanungu_arab_2012) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (UG-W_Kanungu_arab_2012) has insufficient samples (1) for requested cohort size (10), dropping
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/498 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1245 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
#                     cohort  theta_pi  theta_pi_estimate  theta_pi_bias  \
# 0   KE-14_Kilifi_arab_2012  0.012515           0.012513   1.739748e-06
# 1   KE-14_Kilifi_gamb_2000  0.017751           0.017754  -3.812392e-06
# 2   KE-14_Kilifi_gcx3_2012  0.013473           0.013474  -1.341458e-06
# 3   TZ-05_Muleba_arab_2015  0.012306           0.012306   6.185033e-07
# 4   TZ-05_Muleba_gamb_2015  0.021242           0.021247  -4.337053e-06
# 5   TZ-13_Tarime_arab_2012  0.012435           0.012435  -3.120599e-07
# 6   TZ-25_Muheza_gamb_2013  0.017705           0.017705   4.563558e-07
# 7   TZ-25_Muheza_gcx3_2013  0.013395           0.013398  -2.958723e-06
# 8    TZ-26_Moshi_arab_2012  0.012374           0.012373   1.310417e-06
# 9    UG-E_Tororo_arab_2012  0.012560           0.012560   8.203444e-07
# 10   UG-E_Tororo_gamb_2012  0.021693           0.021698  -4.572455e-06
# 11  UG-W_Kanungu_gamb_2012  0.021464           0.021469  -4.432877e-06
#
#     theta_pi_std_err  theta_pi_ci_err  theta_pi_ci_low  theta_pi_ci_upp  \
# 0           0.000221         0.000868         0.012080         0.012947
# 1           0.000281         0.001103         0.017203         0.018306
# 2           0.000276         0.001082         0.012933         0.014015
# 3           0.000224         0.000877         0.011867         0.012744
# 4           0.000302         0.001182         0.020655         0.021838
# 5           0.000220         0.000861         0.012005         0.012866
# 6           0.000290         0.001136         0.017137         0.018273
# 7           0.000342         0.001340         0.012728         0.014068
# 8           0.000219         0.000857         0.011945         0.012801
# 9           0.000224         0.000876         0.012121         0.012998
# 10          0.000317         0.001244         0.021076         0.022320
# 11          0.000310         0.001214         0.020862         0.022076
#
#      theta_w  theta_w_estimate  ...  tajima_d_ci_upp       taxon  year  \
# 0   0.015013          0.015010  ...        -0.649706  arabiensis  2012
# 1   0.018947          0.018950  ...        -0.213639     gambiae  2000
# 2   0.011567          0.011568  ...         0.814804        gcx3  2012
# 3   0.014789          0.014790  ...        -0.658653  arabiensis  2015
# 4   0.030350          0.030352  ...        -1.226721     gambiae  2015
# 5   0.015058          0.015059  ...        -0.681130  arabiensis  2012
# 6   0.018939          0.018935  ...        -0.218096     gambiae  2013
# 7   0.012917          0.012918  ...         0.257321        gcx3  2013
# 8   0.014669          0.014667  ...        -0.604319  arabiensis  2012
# 9   0.015198          0.015195  ...        -0.679454  arabiensis  2012
# 10  0.031458          0.031460  ...        -1.271359     gambiae  2012
# 11  0.030680          0.030685  ...        -1.225296     gambiae  2012
#
#         month   country  admin1_iso     admin1_name  admin2_name  longitude  \
# 0          -1     Kenya       KE-14          Kilifi       Kilifi     39.909
# 1          -1     Kenya       KE-14          Kilifi       Kilifi     39.909
# 2          -1     Kenya       KE-14          Kilifi       Kilifi     39.909
# 3   [3, 4, 6]  Tanzania       TZ-05          Kagera       Muleba     31.621
# 4      [3, 6]  Tanzania       TZ-05          Kagera       Muleba     31.621
# 5           8  Tanzania       TZ-13            Mara       Tarime     34.199
# 6           1  Tanzania       TZ-25           Tanga       Muheza     38.948
# 7           1  Tanzania       TZ-25           Tanga       Muheza     38.948
# 8           8  Tanzania       TZ-26         Manyara        Moshi     37.308
# 9          10    Uganda        UG-E  Eastern Region       Tororo     34.026
# 10         10    Uganda        UG-E  Eastern Region       Tororo     34.026
# 11   [10, 11]    Uganda        UG-W  Western Region      Kanungu     29.701
#
#     latitude
# 0     -3.511
# 1     -3.511
# 2     -3.511
# 3     -1.962
# 4     -1.962
# 5     -1.431
# 6     -4.940
# 7     -4.940
# 8     -3.482
# 9      0.770
# 10     0.770
# 11    -0.751
#
# [12 rows x 31 columns]

# %%
plot_diversity_stats(df_stats_tz_ke_ug_admin2_year, color="taxon")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9547ae0f-3d1a-48a6-8010-92ec9a419065" class="plotly-graph-div" style="height:450px; width:660px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9547ae0f-3d1a-48a6-8010-92ec9a419065")) {                    Plotly.newPlot(                        "9547ae0f-3d1a-48a6-8010-92ec9a419065",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8],["arabiensis","Uganda","UG-E","Eastern Region","Tororo",2012,10]],"error_y":{"array":[0.0008677148549604082,0.0008767828578080531,0.0008610896628349073,0.0008565317306298921,0.0008761307342683302]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"xaxis":"x","y":[0.01251345296362045,0.012305821385764614,0.012435191358870714,0.012372971080334862,0.012559541398764102],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Kenya","KE-14","Kilifi","Kilifi",2000,-1],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1],["gambiae","Uganda","UG-E","Eastern Region","Tororo",2012,10],["gambiae","Uganda","UG-W","Western Region","Kanungu",2012,[10,11]]],"error_y":{"array":[0.0011028237609669467,0.001182458864377038,0.001136199721887595,0.0012438137498370424,0.0012142207472798146]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"xaxis":"x","y":[0.017754352709839806,0.021246519681427135,0.01770499150805352,0.021697622299276548,0.021468674607270158],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0010819664826624748,0.0013401434715671241]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_gcx3_2012","TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="89674814-6da2-4321-a5a7-269f8245da97" class="plotly-graph-div" style="height:450px; width:660px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89674814-6da2-4321-a5a7-269f8245da97")) {                    Plotly.newPlot(                        "89674814-6da2-4321-a5a7-269f8245da97",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8],["arabiensis","Uganda","UG-E","Eastern Region","Tororo",2012,10]],"error_y":{"array":[0.0008870030015599786,0.0009732513776216027,0.0009709442046371612,0.0009124973674744433,0.0009764560480252688]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"xaxis":"x","y":[0.015010036298917529,0.01479018822563256,0.015058888895662042,0.014666991750033907,0.015194834591381426],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Kenya","KE-14","Kilifi","Kilifi",2000,-1],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1],["gambiae","Uganda","UG-E","Eastern Region","Tororo",2012,10],["gambiae","Uganda","UG-W","Western Region","Kanungu",2012,[10,11]]],"error_y":{"array":[0.0011189028489902812,0.0014784123971940868,0.0011770314504906056,0.0015843348168713893,0.001567355360664869]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"xaxis":"x","y":[0.018950259926004156,0.030352491386682584,0.018935395054669256,0.031460215832358245,0.03068491342922568],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0009101509276341317,0.0009724066834559929]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_gcx3_2012","TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","sho ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5714be6a-563f-4d75-ae19-a2aa8a9ff309" class="plotly-graph-div" style="height:450px; width:660px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5714be6a-563f-4d75-ae19-a2aa8a9ff309")) {                    Plotly.newPlot(                        "5714be6a-563f-4d75-ae19-a2aa8a9ff309",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8],["arabiensis","Uganda","UG-E","Eastern Region","Tororo",2012,10]],"error_y":{"array":[0.0969376111494399,0.09298333949876056,0.10060131875886644,0.10453177863777642,0.09723784451490969]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"xaxis":"x","y":[-0.698174737113276,-0.7051445660180288,-0.7314308240562268,-0.6565852582790553,-0.7280731615080003],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Kenya","KE-14","Kilifi","Kilifi",2000,-1],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1],["gambiae","Uganda","UG-E","Eastern Region","Tororo",2012,10],["gambiae","Uganda","UG-W","Western Region","Kanungu",2012,[10,11]]],"error_y":{"array":[0.10264866548531011,0.06535341551175326,0.10950056994601909,0.0626157217837547,0.07113038634033976]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"xaxis":"x","y":[-0.264963322235059,-1.2593981283459053,-0.2728466026281025,-1.3026667094156976,-1.260861549442583],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.2469692741383376,0.20214467901282857]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_gcx3_2012","TZ-25_Muheza_gcx3_2013"],"legendgroup":"gcx3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"gcx3","offsetgroup":"gcx3","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi_gcx3_2012","TZ-25_Muheza_gcx3_2013"],"xaxis": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0fc2236e-ed7c-4840-8404-c371c71a7707" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0fc2236e-ed7c-4840-8404-c371c71a7707")) {                    Plotly.newPlot(                        "0fc2236e-ed7c-4840-8404-c371c71a7707",                        [{"customdata":[["arabiensis","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8],["arabiensis","Uganda","UG-E","Eastern Region","Tororo",2012,10]],"error_x":{"array":[0.0008677148549604082,0.0008767828578080531,0.0008610896628349073,0.0008565317306298921,0.0008761307342683302]},"error_y":{"array":[0.0008870030015599786,0.0009732513776216027,0.0009709442046371612,0.0009124973674744433,0.0009764560480252688]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_arab_2012","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"arabiensis","orientation":"v","showlegend":true,"x":[0.01251345296362045,0.012305821385764614,0.012435191358870714,0.012372971080334862,0.012559541398764102],"xaxis":"x","y":[0.015010036298917529,0.01479018822563256,0.015058888895662042,0.014666991750033907,0.015194834591381426],"yaxis":"y","type":"scatter"},{"customdata":[["gambiae","Kenya","KE-14","Kilifi","Kilifi",2000,-1],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1],["gambiae","Uganda","UG-E","Eastern Region","Tororo",2012,10],["gambiae","Uganda","UG-W","Western Region","Kanungu",2012,[10,11]]],"error_x":{"array":[0.0011028237609669467,0.001182458864377038,0.001136199721887595,0.0012438137498370424,0.0012142207472798146]},"error_y":{"array":[0.0011189028489902812,0.0014784123971940868,0.0011770314504906056,0.0015843348168713893,0.001567355360664869]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_gamb_2000","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"legendgroup":"gambiae","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"gambiae","orientation":"v","showlegend":true,"x":[0.017754352709839806,0.021246519681427135,0.01770499150805352,0.021697622299276548,0.021468674607270158],"xaxis":"x","y":[0.018950259926004156,0.030352491386682584,0.018935395054669256,0.031460215832358245,0.03068491342922568],"yaxis":"y","type":"scatter"},{"customdata":[["gcx3","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_x":{"array":[0.0010819664826624748,0.0013401434715671241]},"error_y":{"array":[0.0009101509276341317,0.0009724066834559929]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customda ...

# %% [markdown]
# Some observations about these results:
#
# * All *An. arabiensis* cohorts show similar diversity. This indicates that all *An. arabiensis* populations from across this region share very similar demographic histories.
# * Diversity in *An. gambiae* from western Tanzania is very similar to both *An. gambiae* cohorts from Uganda. Conversely, diversity in *An. gambiae* from eastern Tanzania is very similar to *An. gambiae* from coastal Kenya. This supports a strong population division within *An. gambiae*, with different demographic histories.
# * Diversity is very similar between the two gcx3 cohorts from coastal Tanzania and Kenya. This indicates that the two gcx3 cohorts are sampled from populations with similar demographic histories. In particular, both cohorts have positive values for Tajima's D, which is consistent with a reduction in population size. We cannot infer the timing or strength of this reduction from Tajima's D alone, but it is interesting to note that these are the only two cohorts with evidence for population reduction, whereas all *An. gambiae* and *An. arabiensis* cohorts have negative Tajima's D, which is consistent with historical population expansion. This certainly adds evidence for an important distinction between the gcx3 taxon and other mosquito taxa in the region.

# %% [markdown]
# **Exercise 2 (English)**
#
# Rerun the diversity analysis for East Africa, adding Mozambique, Malawi and Mayotte. Discuss the patterns you observe with a colleague.
#
# **Exercice 2 (Français)**
#
# Réexécutez l'analyse de la diversité pour l'Afrique de l'Est, en ajoutant le Mozambique, le Malawi et Mayotte. Discutez des tendances que vous observez avec un collègue.

# %%
df_stats_tz_ke_ug_mz_ml_my_admin2_year = ag3.diversity_stats(
    sample_query="country in ['Tanzania', 'Kenya', 'Uganda','Mozambique','Malawi','Mayotte']",
    cohorts="admin2_year",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)

plot_diversity_stats(df_stats_tz_ke_ug_mz_ml_my_admin2_year, color="taxon")
# Out:
# [INFO] cohort (KE-14_Kilifi_arab_2007) has insufficient samples (3) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (KE-14_Kilifi_arab_2007) has insufficient samples (3) for requested cohort size (10), dropping
# [INFO] cohort (MZ-I_Morrumbene_gamb_2003) has insufficient samples (3) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (MZ-I_Morrumbene_gamb_2003) has insufficient samples (3) for requested cohort size (10), dropping
# [INFO] cohort (TZ-05_Muleba_gcx3_2015) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (TZ-05_Muleba_gcx3_2015) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (TZ-25_Muheza_arab_2013) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (TZ-25_Muheza_arab_2013) has insufficient samples (1) for requested cohort size (10), dropping
# [INFO] cohort (UG-W_Kanungu_arab_2012) has insufficient samples (1) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (UG-W_Kanungu_arab_2012) has insufficient samples (1) for requested cohort size (10), dropping
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8e65ae28-fbce-4ea3-a72f-81439ada2606" class="plotly-graph-div" style="height:450px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e65ae28-fbce-4ea3-a72f-81439ada2606")) {                    Plotly.newPlot(                        "8e65ae28-fbce-4ea3-a72f-81439ada2606",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["arabiensis","Malawi","MW-S","Southern Region","Chikwawa",2015,5],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8],["arabiensis","Uganda","UG-E","Eastern Region","Tororo",2012,10]],"error_y":{"array":[0.0008677148549604082,0.0008564634444601615,0.0008767828578080531,0.0008610896628349073,0.0008565317306298921,0.0008761307342683302]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_arab_2012","MW-S_Chikwawa_arab_2015","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi_arab_2012","MW-S_Chikwawa_arab_2015","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"xaxis":"x","y":[0.01251345296362045,0.01225614364803931,0.012305821385764614,0.012435191358870714,0.012372971080334862,0.012559541398764102],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Mayotte","FR-YT","Mayotte","Mayotte",2011,-1],["gambiae","Kenya","KE-14","Kilifi","Kilifi",2000,-1],["gambiae","Mozambique","MZ-I","Inhambane","Morrumbene",2004,[2,3,4]],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1],["gambiae","Uganda","UG-E","Eastern Region","Tororo",2012,10],["gambiae","Uganda","UG-W","Western Region","Kanungu",2012,[10,11]]],"error_y":{"array":[0.001188906965087002,0.0011028237609669467,0.001160816654342349,0.001182458864377038,0.001136199721887595,0.0012438137498370424,0.0012142207472798146]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["FR-YT_Mayotte_gamb_2011","KE-14_Kilifi_gamb_2000","MZ-I_Morrumbene_gamb_2004","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["FR-YT_Mayotte_gamb_2011","KE-14_Kilifi_gamb_2000","MZ-I_Morrumbene_gamb_2004","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"xaxis":"x","y":[0.013209079218096463,0.017754352709839806,0.016383569622287396,0.021246519681427135,0.01770499150805352,0.021697622299276548,0.021468674607270158],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0010819664826624748,0.0013401434715671241]},"hovertemplat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="358a96c6-f92c-44d8-8585-38347a7d1134" class="plotly-graph-div" style="height:450px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("358a96c6-f92c-44d8-8585-38347a7d1134")) {                    Plotly.newPlot(                        "358a96c6-f92c-44d8-8585-38347a7d1134",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["arabiensis","Malawi","MW-S","Southern Region","Chikwawa",2015,5],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8],["arabiensis","Uganda","UG-E","Eastern Region","Tororo",2012,10]],"error_y":{"array":[0.0008870030015599786,0.0009163928033600954,0.0009732513776216027,0.0009709442046371612,0.0009124973674744433,0.0009764560480252688]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_arab_2012","MW-S_Chikwawa_arab_2015","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi_arab_2012","MW-S_Chikwawa_arab_2015","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"xaxis":"x","y":[0.015010036298917529,0.01428358974622539,0.01479018822563256,0.015058888895662042,0.014666991750033907,0.015194834591381426],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Mayotte","FR-YT","Mayotte","Mayotte",2011,-1],["gambiae","Kenya","KE-14","Kilifi","Kilifi",2000,-1],["gambiae","Mozambique","MZ-I","Inhambane","Morrumbene",2004,[2,3,4]],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1],["gambiae","Uganda","UG-E","Eastern Region","Tororo",2012,10],["gambiae","Uganda","UG-W","Western Region","Kanungu",2012,[10,11]]],"error_y":{"array":[0.0009728267302642284,0.0011189028489902812,0.0010372598058975646,0.0014784123971940868,0.0011770314504906056,0.0015843348168713893,0.001567355360664869]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["FR-YT_Mayotte_gamb_2011","KE-14_Kilifi_gamb_2000","MZ-I_Morrumbene_gamb_2004","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["FR-YT_Mayotte_gamb_2011","KE-14_Kilifi_gamb_2000","MZ-I_Morrumbene_gamb_2004","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"xaxis":"x","y":[0.01176332834861205,0.018950259926004156,0.01643000373430504,0.030352491386682584,0.018935395054669256,0.031460215832358245,0.03068491342922568],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.0009101509276341317,0.0009724066834559929]},"hovertemplate":"< ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3668dfb6-ad3f-442d-843f-c5aeb5508d94" class="plotly-graph-div" style="height:450px; width:750px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3668dfb6-ad3f-442d-843f-c5aeb5508d94")) {                    Plotly.newPlot(                        "3668dfb6-ad3f-442d-843f-c5aeb5508d94",                        [{"alignmentgroup":"True","customdata":[["arabiensis","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["arabiensis","Malawi","MW-S","Southern Region","Chikwawa",2015,5],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8],["arabiensis","Uganda","UG-E","Eastern Region","Tororo",2012,10]],"error_y":{"array":[0.0969376111494399,0.09164044874960775,0.09298333949876056,0.10060131875886644,0.10453177863777642,0.09723784451490969]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_arab_2012","MW-S_Chikwawa_arab_2015","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"arabiensis","offsetgroup":"arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["KE-14_Kilifi_arab_2012","MW-S_Chikwawa_arab_2015","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"xaxis":"x","y":[-0.698174737113276,-0.5958547653877028,-0.7051445660180288,-0.7314308240562268,-0.6565852582790553,-0.7280731615080003],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gambiae","Mayotte","FR-YT","Mayotte","Mayotte",2011,-1],["gambiae","Kenya","KE-14","Kilifi","Kilifi",2000,-1],["gambiae","Mozambique","MZ-I","Inhambane","Morrumbene",2004,[2,3,4]],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1],["gambiae","Uganda","UG-E","Eastern Region","Tororo",2012,10],["gambiae","Uganda","UG-W","Western Region","Kanungu",2012,[10,11]]],"error_y":{"array":[0.1882084555180956,0.10264866548531011,0.11686585700141863,0.06535341551175326,0.10950056994601909,0.0626157217837547,0.07113038634033976]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["FR-YT_Mayotte_gamb_2011","KE-14_Kilifi_gamb_2000","MZ-I_Morrumbene_gamb_2004","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["FR-YT_Mayotte_gamb_2011","KE-14_Kilifi_gamb_2000","MZ-I_Morrumbene_gamb_2004","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"xaxis":"x","y":[0.5158923190646044,-0.264963322235059,-0.011829312405983745,-1.2593981283459053,-0.2728466026281025,-1.3026667094156976,-1.260861549442583],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx3","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["gcx3","Tanzania","TZ-25","Tanga","Muheza",2013,1]],"error_y":{"array":[0.2469692741383376,0.20214467901282857]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Countr ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a79d0f8d-9dba-4ebf-a1fa-e5172b95287a" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a79d0f8d-9dba-4ebf-a1fa-e5172b95287a")) {                    Plotly.newPlot(                        "a79d0f8d-9dba-4ebf-a1fa-e5172b95287a",                        [{"customdata":[["arabiensis","Kenya","KE-14","Kilifi","Kilifi",2012,-1],["arabiensis","Malawi","MW-S","Southern Region","Chikwawa",2015,5],["arabiensis","Tanzania","TZ-05","Kagera","Muleba",2015,[3,4,6]],["arabiensis","Tanzania","TZ-13","Mara","Tarime",2012,8],["arabiensis","Tanzania","TZ-26","Manyara","Moshi",2012,8],["arabiensis","Uganda","UG-E","Eastern Region","Tororo",2012,10]],"error_x":{"array":[0.0008677148549604082,0.0008564634444601615,0.0008767828578080531,0.0008610896628349073,0.0008565317306298921,0.0008761307342683302]},"error_y":{"array":[0.0008870030015599786,0.0009163928033600954,0.0009732513776216027,0.0009709442046371612,0.0009124973674744433,0.0009764560480252688]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["KE-14_Kilifi_arab_2012","MW-S_Chikwawa_arab_2015","TZ-05_Muleba_arab_2015","TZ-13_Tarime_arab_2012","TZ-26_Moshi_arab_2012","UG-E_Tororo_arab_2012"],"legendgroup":"arabiensis","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"arabiensis","orientation":"v","showlegend":true,"x":[0.01251345296362045,0.01225614364803931,0.012305821385764614,0.012435191358870714,0.012372971080334862,0.012559541398764102],"xaxis":"x","y":[0.015010036298917529,0.01428358974622539,0.01479018822563256,0.015058888895662042,0.014666991750033907,0.015194834591381426],"yaxis":"y","type":"scatter"},{"customdata":[["gambiae","Mayotte","FR-YT","Mayotte","Mayotte",2011,-1],["gambiae","Kenya","KE-14","Kilifi","Kilifi",2000,-1],["gambiae","Mozambique","MZ-I","Inhambane","Morrumbene",2004,[2,3,4]],["gambiae","Tanzania","TZ-05","Kagera","Muleba",2015,[3,6]],["gambiae","Tanzania","TZ-25","Tanga","Muheza",2013,1],["gambiae","Uganda","UG-E","Eastern Region","Tororo",2012,10],["gambiae","Uganda","UG-W","Western Region","Kanungu",2012,[10,11]]],"error_x":{"array":[0.001188906965087002,0.0011028237609669467,0.001160816654342349,0.001182458864377038,0.001136199721887595,0.0012438137498370424,0.0012142207472798146]},"error_y":{"array":[0.0009728267302642284,0.0011189028489902812,0.0010372598058975646,0.0014784123971940868,0.0011770314504906056,0.0015843348168713893,0.001567355360664869]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["FR-YT_Mayotte_gamb_2011","KE-14_Kilifi_gamb_2000","MZ-I_Morrumbene_gamb_2004","TZ-05_Muleba_gamb_2015","TZ-25_Muheza_gamb_2013","UG-E_Tororo_gamb_2012","UG-W_Kanungu_gamb_2012"],"legendgroup":"gambiae","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"gambiae","orientation":"v","showlegend":true,"x":[0.013209079218096463,0.017754352709839806,0.016383569622287396,0.021246519681427135,0.01770499150805352,0.021697622299276548,0.021468674607270158],"xaxis":"x","y":[0.01176332834861205,0.018950259926004156,0.01643000373430504,0.030352491386682584,0.018935395054669256,0.031460215832358245,0.03068491342922568],"yaxis":"y","type":"scatter"},{"customdata":[["gcx3","Ken ...

# %% [markdown]
# ### Example: Burkina Faso
#
# Finally, let's look at an example where we have data from the same location from multiple years, to illustrate how we might use diversity to monitor populations for signs of recent demographic changes.
#
# In Burkina Faso we have data from the Houet district from 2012 and 2014, for both *An. gambiae* and *An. coluzzii*.

# %%
ag3.count_samples(
    sample_query="country == 'Burkina Faso'"
)
# Out:
# taxon                                                   arabiensis  coluzzii  \
# country      admin1_iso admin1_name   admin2_name year
# Burkina Faso BF-07      Centre-Sud    Bazega      2004           0         0
#              BF-09      Hauts-Bassins Houet       2012           0        82
#                                                   2014           3        53
#
# taxon                                                   gambiae  \
# country      admin1_iso admin1_name   admin2_name year
# Burkina Faso BF-07      Centre-Sud    Bazega      2004       13
#              BF-09      Hauts-Bassins Houet       2012       98
#                                                   2014       46
#
# taxon                                                   intermediate_gambiae_coluzzii
# country      admin1_iso admin1_name   admin2_name year
# Burkina Faso BF-07      Centre-Sud    Bazega      2004                              0
#              BF-09      Hauts-Bassins Houet       2012                              1
#                                                   2014                              0

# %% [markdown]
# **Exercise 3 (English)**
#
# Analyse diversity in Burkina Faso.
#
# Do you observe any differences between *An. gambiae* and *An. coluzzii*?
#
# Do you observe any differences between 2012 and 2014?
#
# **Exercice 3 (Français)**
#
# Analyser la diversité au Burkina Faso.
#
# Observez-vous des différences entre *An. gambiae* et *An. coluzzii*?
#
# Observez-vous des différences entre 2012 et 2014 ?

# %%
df_stats_bf_admin2_year = ag3.diversity_stats(
    sample_query="country in ['Burkina Faso']",
    cohorts="admin2_year",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)

plot_diversity_stats(df_stats_bf_admin2_year, color="taxon")
# Out:
# [INFO] cohort (BF-09_Houet_arab_2014) has insufficient samples (3) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (BF-09_Houet_arab_2014) has insufficient samples (3) for requested cohort size (10), dropping
# Compute SNP allele counts:   0%|          | 0/498 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1577 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1245 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1577 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="dca7df90-23f3-4fd8-b67c-2e9ecf6d1234" class="plotly-graph-div" style="height:450px; width:450px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dca7df90-23f3-4fd8-b67c-2e9ecf6d1234")) {                    Plotly.newPlot(                        "dca7df90-23f3-4fd8-b67c-2e9ecf6d1234",                        [{"alignmentgroup":"True","customdata":[["gambiae","Burkina Faso","BF-07","Centre-Sud","Bazega",2004,[6,7,8]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,7]],"error_y":{"array":[0.0012451486993074253,0.001230101545368281,0.0012157101188267857]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["BF-07_Bazega_gamb_2004","BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-07_Bazega_gamb_2004","BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014"],"xaxis":"x","y":[0.021860437536535885,0.0224194849395608,0.02194000073839854],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,7]],"error_y":{"array":[0.0012577512016636162,0.001274699498372017]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["BF-09_Houet_colu_2012","BF-09_Houet_colu_2014"],"legendgroup":"coluzzii","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"coluzzii","offsetgroup":"coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-09_Houet_colu_2012","BF-09_Houet_colu_2014"],"xaxis":"x","y":[0.02205578355111523,0.021932628716436097],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="54da5a0b-ff38-46f1-beba-16036399a5b1" class="plotly-graph-div" style="height:450px; width:450px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54da5a0b-ff38-46f1-beba-16036399a5b1")) {                    Plotly.newPlot(                        "54da5a0b-ff38-46f1-beba-16036399a5b1",                        [{"alignmentgroup":"True","customdata":[["gambiae","Burkina Faso","BF-07","Centre-Sud","Bazega",2004,[6,7,8]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,7]],"error_y":{"array":[0.0016842950452439246,0.0016107575180961595,0.0015481402385951106]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["BF-07_Bazega_gamb_2004","BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-07_Bazega_gamb_2004","BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014"],"xaxis":"x","y":[0.032490414137377854,0.03369690192751877,0.032293930632421614],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,7]],"error_y":{"array":[0.0015901984461825906,0.0016007718019864447]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["BF-09_Houet_colu_2012","BF-09_Houet_colu_2014"],"legendgroup":"coluzzii","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"coluzzii","offsetgroup":"coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-09_Houet_colu_2012","BF-09_Houet_colu_2014"],"xaxis":"x","y":[0.03170236381560181,0.031077875883962575],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="29cff842-7b8d-4596-be18-d2fcdf60f576" class="plotly-graph-div" style="height:450px; width:450px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29cff842-7b8d-4596-be18-d2fcdf60f576")) {                    Plotly.newPlot(                        "29cff842-7b8d-4596-be18-d2fcdf60f576",                        [{"alignmentgroup":"True","customdata":[["gambiae","Burkina Faso","BF-07","Centre-Sud","Bazega",2004,[6,7,8]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,7]],"error_y":{"array":[0.06364401952646981,0.05979075753891549,0.06004805649196546]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["BF-07_Bazega_gamb_2004","BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-07_Bazega_gamb_2004","BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014"],"xaxis":"x","y":[-1.3734547113977638,-1.4049175276428654,-1.3459010944673855],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,7]],"error_y":{"array":[0.058767057570099396,0.06326514243228343]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["BF-09_Houet_colu_2012","BF-09_Houet_colu_2014"],"legendgroup":"coluzzii","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"coluzzii","offsetgroup":"coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["BF-09_Houet_colu_2012","BF-09_Houet_colu_2014"],"xaxis":"x","y":[-1.2773494750328969,-1.235303542816873],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4d6e6803-77a7-4776-9f2b-4dfa0d52257d" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d6e6803-77a7-4776-9f2b-4dfa0d52257d")) {                    Plotly.newPlot(                        "4d6e6803-77a7-4776-9f2b-4dfa0d52257d",                        [{"customdata":[["gambiae","Burkina Faso","BF-07","Centre-Sud","Bazega",2004,[6,7,8]],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["gambiae","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,7]],"error_x":{"array":[0.0012451486993074253,0.001230101545368281,0.0012157101188267857]},"error_y":{"array":[0.0016842950452439246,0.0016107575180961595,0.0015481402385951106]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["BF-07_Bazega_gamb_2004","BF-09_Houet_gamb_2012","BF-09_Houet_gamb_2014"],"legendgroup":"gambiae","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"gambiae","orientation":"v","showlegend":true,"x":[0.021860437536535885,0.0224194849395608,0.02194000073839854],"xaxis":"x","y":[0.032490414137377854,0.03369690192751877,0.032293930632421614],"yaxis":"y","type":"scatter"},{"customdata":[["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2012,7],["coluzzii","Burkina Faso","BF-09","Hauts-Bassins","Houet",2014,7]],"error_x":{"array":[0.0012577512016636162,0.001274699498372017]},"error_y":{"array":[0.0015901984461825906,0.0016007718019864447]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["BF-09_Houet_colu_2012","BF-09_Houet_colu_2014"],"legendgroup":"coluzzii","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"coluzzii","orientation":"v","showlegend":true,"x":[0.02205578355111523,0.021932628716436097],"xaxis":"x","y":[0.03170236381560181,0.031077875883962575],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44 ...

# %% [markdown]
# ## Well done!
#
# Well done for completing this module on genetic diversity summary statistics!
#
# ### Exercises
#
# Please now launch this notebook in colab, clear the outputs, copy it to your drive and run it from the top, complete the exercises you find along the way.
#
# ### Challenge (English)
#
# Choose any country or geographical region and perform comparative analysis of genetic diversity. Share your findings and conclusions with colleagues.
#
# ### Défi (Français)
#
# Choisissez n'importe quel pays ou région géographique et effectuez une analyse comparative de la diversité génétique. Partagez vos découvertes et conclusions avec vos collègues.

# %%
ag3.sample_metadata().country.unique()
# Out:
# array(['Angola', 'Burkina Faso', 'Democratic Republic of the Congo',
#        'Central African Republic', "Cote d'Ivoire", 'Cameroon', 'Mayotte',
#        'Gabon', 'Ghana', 'Gambia, The', 'Guinea', 'Mali',
#        'Equatorial Guinea', 'Guinea-Bissau', 'Kenya', 'Malawi',
#        'Mozambique', 'Tanzania', 'Uganda', 'Lab Cross'], dtype=object)

# %%
df_stats_tz_ke_ug_mz_ml_my_admin2_year = ag3.diversity_stats(
    sample_query="country in ['Democratic Republic of the Congo','Central African Republic', 'Gabon','Guinea','Equatorial Guinea','Guinea-Bissau']",
    cohorts="admin2_year",
    cohort_size=10,
    region="3L:15,000,000-41,000,000",
    site_mask="gamb_colu_arab",
    site_class="CDS_DEG_4",
)

plot_diversity_stats(df_stats_tz_ke_ug_mz_ml_my_admin2_year, color="taxon")
# Out:
# [INFO] cohort (CF-BGF_Bangui_colu_1993) has insufficient samples (5) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (CF-BGF_Bangui_colu_1993) has insufficient samples (5) for requested cohort size (10), dropping
# [INFO] cohort (CF-BGF_Bangui_gamb_1993) has insufficient samples (2) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (CF-BGF_Bangui_gamb_1993) has insufficient samples (2) for requested cohort size (10), dropping
# [INFO] cohort (GW-GA_Setor-De-Gabv_gamb_2010) has insufficient samples (8) for requested cohort size (10), dropping
# INFO:malariagen_data.anopheles:cohort (GW-GA_Setor-De-Gabv_gamb_2010) has insufficient samples (8) for requested cohort size (10), dropping
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1577 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/1577 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/498 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/498 [00:00<?, ?it/s]
# Compute SNP allele counts:   0%|          | 0/913 [00:00<?, ?it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5ea32426-ea42-42ac-a8a6-15aa8776c016" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ea32426-ea42-42ac-a8a6-15aa8776c016")) {                    Plotly.newPlot(                        "5ea32426-ea42-42ac-a8a6-15aa8776c016",                        [{"alignmentgroup":"True","customdata":[["gambiae","Democratic Republic of the Congo","CD-NU","Nord-Ubangi","Gbadolite",2015,7],["gambiae","Central African Republic","CF-BGF","Bangui","Bangui",1994,1],["gambiae","Gabon","GA-1","Estuaire","Libreville",2000,12],["gambiae","Guinea","GN-F","Faranah","Kissidougou",2012,10],["gambiae","Guinea","GN-N","Nzerekore","Macenta",2012,10],["gambiae","Equatorial Guinea","GQ-BN","Bioko Norte","Malabo",2002,9]],"error_y":{"array":[0.0012683815940083862,0.0012400757142082715,0.0011851511778674746,0.0012297595508428433,0.0012894498954634263,0.0012622905718393449]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["CD-NU_Gbadolite_gamb_2015","CF-BGF_Bangui_gamb_1994","GA-1_Libreville_gamb_2000","GN-F_Kissidougou_gamb_2012","GN-N_Macenta_gamb_2012","GQ-BN_Malabo_gamb_2002"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["CD-NU_Gbadolite_gamb_2015","CF-BGF_Bangui_gamb_1994","GA-1_Libreville_gamb_2000","GN-F_Kissidougou_gamb_2012","GN-N_Macenta_gamb_2012","GQ-BN_Malabo_gamb_2002"],"xaxis":"x","y":[0.021892365095913528,0.022042430788016727,0.01979006897198557,0.021966135733965778,0.021885242863941272,0.02070666010544823],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["coluzzii","Central African Republic","CF-BGF","Bangui","Bangui",1994,1],["coluzzii","Guinea","GN-N","Nzerekore","Macenta",2012,10]],"error_y":{"array":[0.001240223294460856,0.001143372524817691]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["CF-BGF_Bangui_colu_1994","GN-N_Macenta_colu_2012"],"legendgroup":"coluzzii","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"coluzzii","offsetgroup":"coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["CF-BGF_Bangui_colu_1994","GN-N_Macenta_colu_2012"],"xaxis":"x","y":[0.021362450793609603,0.02054604575611299],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx1","Guinea-Bissau","GW-BM","Biombo","Setor De Safim",2010,-1],["gcx1","Guinea-Bissau","GW-BS","Bissau","Bissau Autonomous Sector",2010,-1]],"error_y":{"array":[0.0012156644166510437,0.0012318012943490087]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{\\pi}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["GW-BM_Setor-De-Safim_gcx1_2010","GW-BS_Bissau-Autonomous-Sector_gcx1_2010"],"legendgroup":"gcx1","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"gcx1","offsetgroup":"gcx1","orientation":"v","showlegend":true,"textposition":"auto","x":["GW-BM_Setor-De-Safim_gcx1_2010","GW-BS_Bissau-Autonomous-Sector_gcx1_2010"],"xaxis":"x","y":[0.022113706273 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b7a27454-b460-4628-a145-2fe78daff7a9" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7a27454-b460-4628-a145-2fe78daff7a9")) {                    Plotly.newPlot(                        "b7a27454-b460-4628-a145-2fe78daff7a9",                        [{"alignmentgroup":"True","customdata":[["gambiae","Democratic Republic of the Congo","CD-NU","Nord-Ubangi","Gbadolite",2015,7],["gambiae","Central African Republic","CF-BGF","Bangui","Bangui",1994,1],["gambiae","Gabon","GA-1","Estuaire","Libreville",2000,12],["gambiae","Guinea","GN-F","Faranah","Kissidougou",2012,10],["gambiae","Guinea","GN-N","Nzerekore","Macenta",2012,10],["gambiae","Equatorial Guinea","GQ-BN","Bioko Norte","Malabo",2002,9]],"error_y":{"array":[0.0015722446352255195,0.0016270349085452409,0.0014318574912137818,0.001573819173268246,0.0016686217696051768,0.0014576992490243023]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["CD-NU_Gbadolite_gamb_2015","CF-BGF_Bangui_gamb_1994","GA-1_Libreville_gamb_2000","GN-F_Kissidougou_gamb_2012","GN-N_Macenta_gamb_2012","GQ-BN_Malabo_gamb_2002"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["CD-NU_Gbadolite_gamb_2015","CF-BGF_Bangui_gamb_1994","GA-1_Libreville_gamb_2000","GN-F_Kissidougou_gamb_2012","GN-N_Macenta_gamb_2012","GQ-BN_Malabo_gamb_2002"],"xaxis":"x","y":[0.03191583565197898,0.03289505399573455,0.02296058636842884,0.03251589761061805,0.032473414092652614,0.02638358900976985],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["coluzzii","Central African Republic","CF-BGF","Bangui","Bangui",1994,1],["coluzzii","Guinea","GN-N","Nzerekore","Macenta",2012,10]],"error_y":{"array":[0.0014890067478074017,0.0012166850666424423]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["CF-BGF_Bangui_colu_1994","GN-N_Macenta_colu_2012"],"legendgroup":"coluzzii","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"coluzzii","offsetgroup":"coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["CF-BGF_Bangui_colu_1994","GN-N_Macenta_colu_2012"],"xaxis":"x","y":[0.0302908869668604,0.023180426632843],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx1","Guinea-Bissau","GW-BM","Biombo","Setor De Safim",2010,-1],["gcx1","Guinea-Bissau","GW-BS","Bissau","Bissau Autonomous Sector",2010,-1]],"error_y":{"array":[0.0015234060972524794,0.0015352481973325508]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["GW-BM_Setor-De-Safim_gcx1_2010","GW-BS_Bissau-Autonomous-Sector_gcx1_2010"],"legendgroup":"gcx1","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"gcx1","offsetgroup":"gcx1","orientation":"v","showlegend":true,"textposition":"auto","x":["GW-BM_Setor-De-Safim_gcx1_2010","GW-BS_Bissau-Autonomous-Sector_gcx1_2010"],"xaxis":"x","y":[0.031224439530846543,0.031016 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5b982a6b-5151-426e-b08f-f9b0d30526e2" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b982a6b-5151-426e-b08f-f9b0d30526e2")) {                    Plotly.newPlot(                        "5b982a6b-5151-426e-b08f-f9b0d30526e2",                        [{"alignmentgroup":"True","customdata":[["gambiae","Democratic Republic of the Congo","CD-NU","Nord-Ubangi","Gbadolite",2015,7],["gambiae","Central African Republic","CF-BGF","Bangui","Bangui",1994,1],["gambiae","Gabon","GA-1","Estuaire","Libreville",2000,12],["gambiae","Guinea","GN-F","Faranah","Kissidougou",2012,10],["gambiae","Guinea","GN-N","Nzerekore","Macenta",2012,10],["gambiae","Equatorial Guinea","GQ-BN","Bioko Norte","Malabo",2002,9]],"error_y":{"array":[0.06768267030837373,0.05878227477477462,0.09908243788495737,0.06103595270484269,0.058297072385086954,0.07715338337335174]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["CD-NU_Gbadolite_gamb_2015","CF-BGF_Bangui_gamb_1994","GA-1_Libreville_gamb_2000","GN-F_Kissidougou_gamb_2012","GN-N_Macenta_gamb_2012","GQ-BN_Malabo_gamb_2002"],"legendgroup":"gambiae","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"gambiae","offsetgroup":"gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["CD-NU_Gbadolite_gamb_2015","CF-BGF_Bangui_gamb_1994","GA-1_Libreville_gamb_2000","GN-F_Kissidougou_gamb_2012","GN-N_Macenta_gamb_2012","GQ-BN_Malabo_gamb_2002"],"xaxis":"x","y":[-1.3183748315200734,-1.3849519754948776,-0.579800653191333,-1.361996318922985,-1.3687363350455517,-0.9032590183864603],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["coluzzii","Central African Republic","CF-BGF","Bangui","Bangui",1994,1],["coluzzii","Guinea","GN-N","Nzerekore","Macenta",2012,10]],"error_y":{"array":[0.060740768917098675,0.06987899500028881]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["CF-BGF_Bangui_colu_1994","GN-N_Macenta_colu_2012"],"legendgroup":"coluzzii","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"coluzzii","offsetgroup":"coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["CF-BGF_Bangui_colu_1994","GN-N_Macenta_colu_2012"],"xaxis":"x","y":[-1.2373257881868218,-0.47708640891532866],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["gcx1","Guinea-Bissau","GW-BM","Biombo","Setor De Safim",2010,-1],["gcx1","Guinea-Bissau","GW-BS","Bissau","Bissau Autonomous Sector",2010,-1]],"error_y":{"array":[0.06310517268431065,0.06557644859595413]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>Cohort=%{x}<br>$D$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["GW-BM_Setor-De-Safim_gcx1_2010","GW-BS_Bissau-Autonomous-Sector_gcx1_2010"],"legendgroup":"gcx1","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"gcx1","offsetgroup":"gcx1","orientation":"v","showlegend":true,"textposition":"auto","x":["GW-BM_Setor-De-Safim_gcx1_2010","GW-BS_Bissau-Autonomous-Sector_gcx1_2010"],"xaxis":"x","y":[-1.2248722674261336,-1.2120181496471445],"yaxis":"y","type":"bar"}],                        {"template":{"da ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="31a07db6-5c72-48b8-94d0-e4ca91455ffc" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31a07db6-5c72-48b8-94d0-e4ca91455ffc")) {                    Plotly.newPlot(                        "31a07db6-5c72-48b8-94d0-e4ca91455ffc",                        [{"customdata":[["gambiae","Democratic Republic of the Congo","CD-NU","Nord-Ubangi","Gbadolite",2015,7],["gambiae","Central African Republic","CF-BGF","Bangui","Bangui",1994,1],["gambiae","Gabon","GA-1","Estuaire","Libreville",2000,12],["gambiae","Guinea","GN-F","Faranah","Kissidougou",2012,10],["gambiae","Guinea","GN-N","Nzerekore","Macenta",2012,10],["gambiae","Equatorial Guinea","GQ-BN","Bioko Norte","Malabo",2002,9]],"error_x":{"array":[0.0012683815940083862,0.0012400757142082715,0.0011851511778674746,0.0012297595508428433,0.0012894498954634263,0.0012622905718393449]},"error_y":{"array":[0.0015722446352255195,0.0016270349085452409,0.0014318574912137818,0.001573819173268246,0.0016686217696051768,0.0014576992490243023]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["CD-NU_Gbadolite_gamb_2015","CF-BGF_Bangui_gamb_1994","GA-1_Libreville_gamb_2000","GN-F_Kissidougou_gamb_2012","GN-N_Macenta_gamb_2012","GQ-BN_Malabo_gamb_2002"],"legendgroup":"gambiae","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"gambiae","orientation":"v","showlegend":true,"x":[0.021892365095913528,0.022042430788016727,0.01979006897198557,0.021966135733965778,0.021885242863941272,0.02070666010544823],"xaxis":"x","y":[0.03191583565197898,0.03289505399573455,0.02296058636842884,0.03251589761061805,0.032473414092652614,0.02638358900976985],"yaxis":"y","type":"scatter"},{"customdata":[["coluzzii","Central African Republic","CF-BGF","Bangui","Bangui",1994,1],["coluzzii","Guinea","GN-N","Nzerekore","Macenta",2012,10]],"error_x":{"array":[0.001240223294460856,0.001143372524817691]},"error_y":{"array":[0.0014890067478074017,0.0012166850666424423]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["CF-BGF_Bangui_colu_1994","GN-N_Macenta_colu_2012"],"legendgroup":"coluzzii","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"coluzzii","orientation":"v","showlegend":true,"x":[0.021362450793609603,0.02054604575611299],"xaxis":"x","y":[0.0302908869668604,0.023180426632843],"yaxis":"y","type":"scatter"},{"customdata":[["gcx1","Guinea-Bissau","GW-BM","Biombo","Setor De Safim",2010,-1],["gcx1","Guinea-Bissau","GW-BS","Bissau","Bissau Autonomous Sector",2010,-1]],"error_x":{"array":[0.0012156644166510437,0.0012318012943490087]},"error_y":{"array":[0.0015234060972524794,0.0015352481973325508]},"hovertemplate":"<b>%{hovertext}</b><br><br>Taxon=%{customdata[0]}<br>$\\widehat{\\theta}_{\\pi}$=%{x}<br>$\\widehat{\\theta}_{w}$=%{y}<br>Country=%{customdata[1]}<br>admin1_iso=%{customdata[2]}<br>admin1_name=%{customdata[3]}<br>admin2_name=%{customdata[4]}<br>year=%{customdata[5]}<br>month=%{customdata[6]}<extra></extra>","hovertext":["GW-BM_Setor-De-Safim_gcx1_2010","GW-BS_Bissau-Autonomous-Sector_gcx1_2010"],"legendgroup":"gcx1","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"gcx1","orientation":"v","showlegen ...
